# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# We have a dataset with details of a bank's customers, and the target variable is a binary variable that reflects whether the customer has left the bank (closed his/her account) or remains a customer.
#
# The features in the given dataset are:
# - **rownumber:** Row Numbers from 1 to 10000.
# - **customerid:** A unique ID that identifies each customer.
# - **surname:** The customer’s surname.
# - **creditscore:** A credit score is a number between 300–850 that depicts a consumer's creditworthiness.
# - **geography:** The country from which the customer belongs to.
# - **Gender:** The customer’s gender: Male, Female
# - **Age:** The customer’s current age, in years, at the time of being customer.
# - **tenure:** The number of years for which the customer has been with the bank.
# - **balance:** Bank balance of the customer.
# - **numofproducts:** the number of bank products the customer is utilising.
# - **hascrcard:** The number of credit cards given to the customer by the bank.
# - **isactivemember:** Binary Flag for indicating if the client is active or not with the bank before the moment where the client exits the company (recorded in the variable "exited")
# - **exited:** Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Import  libraries & data

# %%
# tfcpu envoirement used
# !pip install livelossplot

# %%
# Importing the libraries for EDA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12, 6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# Importing libraries for DL and ML
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import recall_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import GridSearchCV, HalvingGridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from livelossplot import PlotLossesKerasTF #

# %%
df = pd.read_csv("Churn_Modelling.csv", index_col='RowNumber')
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.000              1          1               1
# 2          83807.860              1          0               1
# 3         159660.800              3          1               0
# 4              0.000              2          0               0
# 5         125510.820              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1               101348.880       1
# 2               112542.580       0
# 3               113931.570       1
# 4                93826.630       0
# 5                79084.100       0

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.isnull().sum().any() # No missing values
# Out:
# False

# %%
df.duplicated().sum() # No duplicates
# Out:
# 0

# %%
df.describe().T # summary statistics
# Out:
#                     count         mean       std          min          25%  \
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
df.drop(['CustomerId', 'Surname'], axis=1, inplace=True)

# %%
ax = sns.countplot(df["Exited"])
ax.set_title("Target Distrubution")
ax.bar_label(ax.containers[0]);

# %%
#!pip install sweetviz

# %%
import sweetviz # for visualizing the data

my_report = sweetviz.analyze([df, "original data"],target_feat='Exited')

my_report.show_notebook(layout="vertical", w ="980", h= 700, scale= .8)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="980" height="700" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,4,1)
ax = sns.boxplot(y = df["Balance"])

plt.subplot(1,4,2)
ax = sns.boxplot(y = df["EstimatedSalary"])

plt.subplot(1,4,3)
ax = sns.boxplot(y = df["CreditScore"])

plt.subplot(1,4,4)
ax = sns.boxplot(y = df["Age"]);

# %%
df.hist(figsize=(15, 12), bins=15, xrot=90);
plt.tight_layout()

# %%
cat_list = ["Gender", "HasCrCard", "IsActiveMember", "Geography"]
index = 0
plt.figure(figsize=(16, 8))
for i in cat_list:
    index += 1
    plt.subplot(2, 2, index)
    ax = sns.countplot(data=df, x=i, hue="Exited")
    for i in ax.containers:
        ax.bar_label(i);

# %%
df.groupby("Age")["Exited"].value_counts()
# Out:
# Age  Exited
# 18   0         20
#      1          2
# 19   0         26
#      1          1
# 20   0         38
#                ..
# 84   0          1
#      1          1
# 85   0          1
# 88   0          1
# 92   0          2
# Name: Exited, Length: 128, dtype: int64

# %%
plt.figure(figsize=(20, 7))
sns.countplot(df.Age, hue=df.Exited);

# %%
df.CreditScore.describe()
# Out:
# count   10000.000
# mean      650.529
# std        96.653
# min       350.000
# 25%       584.000
# 50%       652.000
# 75%       718.000
# max       850.000
# Name: CreditScore, dtype: float64

# %%
def credit_transformer(x, y):
    """to prodduce a new value by using credit score and has credit card"""

    if x < 350 and y == 0:
        return 0
    if x < 350 and y > 0:
        return 1
    if x < 718 and y == 0:
        return 2
    if x < 718 and y > 0:
        return 3
    else:
        return 4

# %%
customer_value = [credit_transformer(x, y) for x, y in zip(df.CreditScore, df.HasCrCard)]
customer_value[:10]
# Out:
# [3, 2, 3, 2, 4, 3, 4, 3, 2, 3]

# %%
df.insert(10, "customer_value", customer_value)

# %%
df.customer_value
# Out:
# RowNumber
# 1        3
# 2        2
# 3        3
# 4        2
# 5        4
#         ..
# 9996     4
# 9997     3
# 9998     2
# 9999     4
# 10000    4
# Name: customer_value, Length: 10000, dtype: int64

# %% [markdown]
# ----

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True, cmap='viridis',vmin= -1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
ax = df.corr()['Exited'][:-1].sort_values().plot.bar()
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ## Preprocessing of Data

# %%
X = df.drop('Exited', axis=1)
y = df['Exited'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=y, test_size=0.15, random_state=42)

# %%
cat_col = X_train.select_dtypes(include=['object', 'bool']).columns

encoder = OneHotEncoder(categories="auto",
                        sparse=False, 
                        drop="first", 
                        handle_unknown="ignore")

# %%
transformers=[('cat', encoder ,cat_col)]

col_transformer = ColumnTransformer(transformers=transformers, remainder='passthrough')

# %%
X_train = col_transformer.fit_transform(X_train)
X_test = col_transformer.transform(X_test)

# %%
scaler = MinMaxScaler() # Minmax scaler mostly used for deep learning as a rule of thumb

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Modelling & Model Performance

# %% [markdown]
# <span class="mark">How many hidden layers should I use? : http://www.faqs.org/faqs/ai-faq/neural-nets/part3/section-9.html (mirror: http://francky.me/aifaq/FAQ-comp.ai.neural-net.pdf)
# How many hidden units should I use? : http://www.faqs.org/faqs/ai-faq/neural-nets/part3/section-10.html (mirror: http://francky.me/aifaq/FAQ-comp.ai.neural-net.pdf)
# What is genetic algorithm? : https://www.researchgate.net/post/What_is_genetic_algorithm1
# Genetic algorithm + neural networks: http://francky.me/doc/mrf2011-HEC-ISIR-ENS_en.pdf (chapter 2.2)</span>

# %% [markdown]
# ### without class_weigth

# %%
tf.random.set_seed(42) # for reproducibility

model = Sequential() # instantiate the model

model.add(Dense(16, activation="relu")) # add the input layer and the first hidden layer
model.add(Dense(8, activation="relu"))  # add the second hidden layer
model.add(Dense(1, activation="sigmoid")) # add the output layer

opt = Adam(lr=0.001) # optimizer 
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"]) # loss function and metrics

# %% [markdown]
# <span class="burk">The patience is often set somewhere between 10 and 100 (10 or 20 is more common), but it really depends on your dataset and network.</span>

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=11,
                           restore_best_weights = True)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop,PlotLossesKerasTF()])
# Out:
# Loss
# 	training         	 (min:    0.329, max:    0.528, cur:    0.330)
# 	validation       	 (min:    0.339, max:    0.494, cur:    0.340)
# recall
# 	training         	 (min:    0.000, max:    0.491, cur:    0.481)
# 	validation       	 (min:    0.000, max:    0.529, cur:    0.500)
# 60/60 [==============================] - 0s 5ms/step - loss: 0.3299 - recall: 0.4811 - val_loss: 0.3397 - val_recall: 0.5000
# Epoch 00102: early stopping

# %%
model.summary() # summary of the model, how many layers, how many nodes in each layer
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                208
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 353
# Trainable params: 353
# Non-trainable params: 0
# _________________________________________________________________

# %%
# loss function history for each epoch
loss_df = pd.DataFrame(model.history.history) 
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > .5).astype("int32") # to convert the probabilities into binary values
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1129   65]
#  [ 159  147]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1194
#            1       0.69      0.48      0.57       306
#
#     accuracy                           0.85      1500
#    macro avg       0.78      0.71      0.74      1500
# weighted avg       0.84      0.85      0.84      1500

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %%
non_weighted_pre_score = average_precision_score(y_test, y_pred_proba)
non_weighted_pre_score
# Out:
# 0.6813477909847775

# %%
non_weighted_f1 = f1_score(y_test, y_pred)
non_weighted_recall = recall_score(y_test, y_pred)

# %% [markdown]
# ### with class_weigth

# %%
tf.random.set_seed(42)

model = Sequential()

model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=10,
                           restore_best_weights = True)

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.6278623134879598, 1: 2.455228191796649}

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop,PlotLossesKerasTF()],
          class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.504, max:    0.696, cur:    0.504)
# 	validation       	 (min:    0.520, max:    0.672, cur:    0.543)
# recall
# 	training         	 (min:    0.235, max:    0.771, cur:    0.768)
# 	validation       	 (min:    0.529, max:    0.735, cur:    0.735)
# 60/60 [==============================] - 0s 5ms/step - loss: 0.5044 - recall: 0.7681 - val_loss: 0.5432 - val_recall: 0.7353
# Epoch 00031: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > .5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[923 271]
#  [100 206]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83      1194
#            1       0.43      0.67      0.53       306
#
#     accuracy                           0.75      1500
#    macro avg       0.67      0.72      0.68      1500
# weighted avg       0.81      0.75      0.77      1500

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %%
weighted_pre_score = average_precision_score(y_test, y_pred_proba)
weighted_pre_score
# Out:
# 0.5094393144904867

# %%
weighted_f1 = f1_score(y_test, y_pred)
weighted_recall = recall_score(y_test, y_pred)

# %% [markdown]
# ## GridSearchCV

# %%
# to use the model in sklearn
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# optimizers for gradient descent to use in backpropagation
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam

# %%
# function to build the model
def build_classifier(optimizer,learn_rate): 
    tf.random.set_seed(42)
    classifier = Sequential()
    classifier.add(Dense(units=16, activation='relu'))
    classifier.add(Dense(units=8, activation='relu'))
    classifier.add(Dense(units=1, activation='sigmoid'))
    classifier.compile(optimizer=optimizer(learn_rate),
                       loss='binary_crossentropy',
                       metrics=['Recall'])
    return classifier

# %%
class_weights
# Out:
# {0: 0.6278623134879598, 1: 2.455228191796649}

# %%
classifier = KerasClassifier(build_fn=build_classifier, 
                             validation_split = 0.1, 
                             epochs=150) # instantiate the classifier
parameters = {
    'batch_size': [128, 256],
    'optimizer': [Adam, RMSprop] #, Adadelta, Nadam],
    'learn_rate': [0.001, 0.003,0.004]
} # parameters to tune
grid_model = GridSearchCV(estimator=classifier,
                          param_grid=parameters,
                          scoring='recall',
                          cv=5,
                          n_jobs=-1,
                          verbose=1).fit(X_train,
                                         y_train,
                                         class_weight=class_weights,
                                         ) # grid search to find the best parameters
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Epoch 1/150
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6798 - recall: 0.4606 - val_loss: 0.6842 - val_recall: 0.6941
# Epoch 2/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6387 - recall: 0.6361 - val_loss: 0.6471 - val_recall: 0.6000
# Epoch 3/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6171 - recall: 0.6605 - val_loss: 0.6510 - val_recall: 0.6824
# Epoch 4/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6022 - recall: 0.7143 - val_loss: 0.5510 - val_recall: 0.4941
# Epoch 5/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5893 - recall: 0.7047 - val_loss: 0.6419 - val_recall: 0.7176
# Epoch 6/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5748 - recall: 0.7245 - val_loss: 0.6108 - val_recall: 0.6882
# Epoch 7/150
# 30/30 [==============================] - 0s 989us/step - loss: 0.5628 - recall: 0.7162 - val_loss: 0.6539 - val_recall: 0.7412
# Epoch 8/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5541 - recall: 0.7431 - val_loss: 0.5607 - val_recall: 0.6588
# Epoch 9/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5444 - recall: 0.7418 - val_loss: 0.6237 - val_recall: 0.7353
# Epoch 10/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5373 - recall: 0.7476 - val_loss: 0.5562 - val_recall: 0.7000
# Epoch 11/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5266 - recall: 0.7457 - val_loss: 0.5764 - val_recall: 0.7176
# Epoch 12/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5186 - recall: 0.7521 - val_loss: 0.5883 - val_recall: 0.7353
# Epoch 13/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5096 - recall: 0.7540 - val_loss: 0.5812 - val_recall: 0.7647
# Epoch 14/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5040 - recall: 0.7719 - val_loss: 0.5070 - val_recall: 0.6941
# Epoch 15/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5003 - recall: 0.7636 - val_loss: 0.5390 - val_recall: 0.7471
# Epoch 16/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4944 - recall: 0.7598 - val_loss: 0.5401 - val_recall: 0.7529
# Epoch 17/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4944 - recall: 0.7649 - val_loss: 0.5504 - val_recall: 0.7882
# Epoch 18/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4905 - recall: 0.7662 - val_loss: 0.5669 - val_recall: 0.8000
# Epoch 19/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4846 - recall: 0.7611 - val_loss: 0.4908 - val_recall: 0.7471
# Epoch 20/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4813 - recall: 0.7822 - val_loss: 0.4936 - val_recall: 0.7471
# Epoch 21/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4787 - recall: 0.7623 - val_loss: 0.4528 - val_recall: 0.6941
# Epoch 22/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4790 - recall: 0.7668 - val_loss: 0.5419 - val_recall: 0.8000
# Epoch 23/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4756 - recall: 0.7694 - val_loss: 0.4330 - val_recall: 0.6706
# Epoch 24/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4757 - recall: 0.7623 - val_loss: 0.5466 - val_recall: 0.7706
# Epoch 25/150
# 30/30 [==============================] - 0s 974us/step - loss: 0.4761 - recall: 0.7675 - val_loss: 0.4810 - val_recall: 0.7353
# Epoch 26/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4706 - recall: 0.7630 - val_loss: 0.4823 - val_recall: 0.7412
# Epoch 27/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4708 - recall: 0.7694 - val_loss: 0.4850 - val_recall: 0.7353
# Epoch 28/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4686 - recall: 0.7719 - val_loss: 0.4789 - val_recall: 0.7412
# Epoch 29/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4722 - recall: 0.7668 - val_loss: 0.4418 - val_recall: 0.7059
# Epoch 30/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4699 - recall: 0.7655 - val_loss: 0.4785 - val_recall: 0.7353
# Epoch 31/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4649 - recall: 0.7700 - val_loss: 0.4745 - val_recall: 0.7353
# Epoch 32/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4642 - recall: 0.7611 - val_loss: 0.4406 - val_recall: 0.7235
# Epoch 33/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4647 - recall: 0.7617 - val_loss: 0.5177 - val_recall: 0.7706
# Epoch 34/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4640 - recall: 0.7726 - val_loss: 0.4933 - val_recall: 0.7588
# Epoch 35/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4649 - recall: 0.7713 - val_loss: 0.4364 - val_recall: 0.7059
# Epoch 36/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4619 - recall: 0.7649 - val_loss: 0.4108 - val_recall: 0.6882
# Epoch 37/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4648 - recall: 0.7611 - val_loss: 0.4766 - val_recall: 0.7412
# Epoch 38/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4630 - recall: 0.7668 - val_loss: 0.4590 - val_recall: 0.7353
# Epoch 39/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4601 - recall: 0.7662 - val_loss: 0.4705 - val_recall: 0.7412
# Epoch 40/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4566 - recall: 0.7662 - val_loss: 0.4658 - val_recall: 0.7471
# Epoch 41/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4628 - recall: 0.7643 - val_loss: 0.5181 - val_recall: 0.7882
# Epoch 42/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4587 - recall: 0.7566 - val_loss: 0.5019 - val_recall: 0.7706
# Epoch 43/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4606 - recall: 0.7732 - val_loss: 0.4930 - val_recall: 0.7706
# Epoch 44/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4621 - recall: 0.7771 - val_loss: 0.4449 - val_recall: 0.7294
# Epoch 45/150
# 30/30 [==============================] - 0s 945us/step - loss: 0.4569 - recall: 0.7662 - val_loss: 0.4474 - val_recall: 0.7412
# Epoch 46/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4565 - recall: 0.7726 - val_loss: 0.4736 - val_recall: 0.7529
# Epoch 47/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4576 - recall: 0.7751 - val_loss: 0.4318 - val_recall: 0.7176
# Epoch 48/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4589 - recall: 0.7630 - val_loss: 0.5049 - val_recall: 0.7765
# Epoch 49/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4576 - recall: 0.7675 - val_loss: 0.4882 - val_recall: 0.7647
# Epoch 50/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4599 - recall: 0.7771 - val_loss: 0.4518 - val_recall: 0.7529
# Epoch 51/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4538 - recall: 0.7694 - val_loss: 0.5187 - val_recall: 0.7765
# Epoch 52/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4542 - recall: 0.7777 - val_loss: 0.4383 - val_recall: 0.7529
# Epoch 53/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4536 - recall: 0.7655 - val_loss: 0.4418 - val_recall: 0.7353
# Epoch 54/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4537 - recall: 0.7790 - val_loss: 0.4609 - val_recall: 0.7529
# Epoch 55/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4515 - recall: 0.7751 - val_loss: 0.4052 - val_recall: 0.6706
# Epoch 56/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4577 - recall: 0.7687 - val_loss: 0.5026 - val_recall: 0.7765
# Epoch 57/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4568 - recall: 0.7771 - val_loss: 0.4653 - val_recall: 0.7471
# Epoch 58/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4507 - recall: 0.7655 - val_loss: 0.5449 - val_recall: 0.8059
# Epoch 59/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4558 - recall: 0.7905 - val_loss: 0.4387 - val_recall: 0.7235
# Epoch 60/150
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4500 - recall: 0.7822 - val_loss: 0.4470 - val_recall: 0.7471
# Epoch 61/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4527 - recall: 0.7726 - val_loss: 0.4767 - val_recall: 0.7529
# Epoch 62/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4522 - recall: 0.7713 - val_loss: 0.4498 - val_recall: 0.7412
# Epoch 63/150
# 30/30 [==============================] - 0s 999us/step - loss: 0.4503 - recall: 0.7707 - val_loss: 0.4679 - val_recall: 0.7471
# Epoch 64/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4494 - recall: 0.7790 - val_loss: 0.4526 - val_recall: 0.7471
# Epoch 65/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4515 - recall: 0.7841 - val_loss: 0.4501 - val_recall: 0.7235
# Epoch 66/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4511 - recall: 0.7687 - val_loss: 0.5001 - val_recall: 0.7941
# Epoch 67/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4493 - recall: 0.7880 - val_loss: 0.4557 - val_recall: 0.7471
# Epoch 68/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4497 - recall: 0.7739 - val_loss: 0.4325 - val_recall: 0.7176
# Epoch 69/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4478 - recall: 0.7719 - val_loss: 0.4524 - val_recall: 0.7353
# Epoch 70/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4473 - recall: 0.7841 - val_loss: 0.4218 - val_recall: 0.6941
# Epoch 71/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4497 - recall: 0.7713 - val_loss: 0.4475 - val_recall: 0.7353
# Epoch 72/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4478 - recall: 0.7841 - val_loss: 0.4773 - val_recall: 0.7588
# Epoch 73/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4490 - recall: 0.7771 - val_loss: 0.4850 - val_recall: 0.7529
# Epoch 74/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4463 - recall: 0.7783 - val_loss: 0.4699 - val_recall: 0.7529
# Epoch 75/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4453 - recall: 0.7880 - val_loss: 0.4307 - val_recall: 0.7235
# Epoch 76/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4445 - recall: 0.7822 - val_loss: 0.4259 - val_recall: 0.7235
# Epoch 77/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4454 - recall: 0.7816 - val_loss: 0.4807 - val_recall: 0.7588
# Epoch 78/150
# 30/30 [==============================] - 0s 996us/step - loss: 0.4498 - recall: 0.7783 - val_loss: 0.5059 - val_recall: 0.7647
# Epoch 79/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4468 - recall: 0.7873 - val_loss: 0.4593 - val_recall: 0.7529
# Epoch 80/150
# 30/30 [==============================] - 0s 997us/step - loss: 0.4474 - recall: 0.7905 - val_loss: 0.4629 - val_recall: 0.7529
# Epoch 81/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4448 - recall: 0.7899 - val_loss: 0.4230 - val_recall: 0.7235
# Epoch 82/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4435 - recall: 0.7880 - val_loss: 0.4230 - val_recall: 0.7235
# Epoch 83/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4455 - recall: 0.7739 - val_loss: 0.4568 - val_recall: 0.7471
# Epoch 84/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4455 - recall: 0.7956 - val_loss: 0.4898 - val_recall: 0.7647
# Epoch 85/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4446 - recall: 0.7854 - val_loss: 0.4344 - val_recall: 0.7471
# Epoch 86/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4428 - recall: 0.7963 - val_loss: 0.4026 - val_recall: 0.6824
# Epoch 87/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4504 - recall: 0.7828 - val_loss: 0.4423 - val_recall: 0.7235
# Epoch 88/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4436 - recall: 0.7899 - val_loss: 0.4113 - val_recall: 0.7000
# Epoch 89/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4457 - recall: 0.7892 - val_loss: 0.4445 - val_recall: 0.7471
# Epoch 90/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4419 - recall: 0.7816 - val_loss: 0.4468 - val_recall: 0.7471
# Epoch 91/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4416 - recall: 0.7892 - val_loss: 0.5041 - val_recall: 0.7706
# Epoch 92/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4427 - recall: 0.7873 - val_loss: 0.4705 - val_recall: 0.7588
# Epoch 93/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4402 - recall: 0.7860 - val_loss: 0.4468 - val_recall: 0.7294
# Epoch 94/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4413 - recall: 0.7867 - val_loss: 0.4444 - val_recall: 0.7353
# Epoch 95/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4405 - recall: 0.7988 - val_loss: 0.4497 - val_recall: 0.7471
# Epoch 96/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4387 - recall: 0.7924 - val_loss: 0.4793 - val_recall: 0.7588
# Epoch 97/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4386 - recall: 0.7867 - val_loss: 0.4845 - val_recall: 0.7647
# Epoch 98/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4401 - recall: 0.7918 - val_loss: 0.4737 - val_recall: 0.7529
# Epoch 99/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4422 - recall: 0.7950 - val_loss: 0.4229 - val_recall: 0.7176
# Epoch 100/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4392 - recall: 0.7886 - val_loss: 0.4888 - val_recall: 0.7706
# Epoch 101/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4431 - recall: 0.7816 - val_loss: 0.4135 - val_recall: 0.7059
# Epoch 102/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4464 - recall: 0.7892 - val_loss: 0.4703 - val_recall: 0.7765
# Epoch 103/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4394 - recall: 0.7950 - val_loss: 0.4996 - val_recall: 0.7824
# Epoch 104/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4416 - recall: 0.7880 - val_loss: 0.5425 - val_recall: 0.8235
# Epoch 105/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4411 - recall: 0.7860 - val_loss: 0.4907 - val_recall: 0.7706
# Epoch 106/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4399 - recall: 0.7886 - val_loss: 0.4950 - val_recall: 0.7824
# Epoch 107/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4403 - recall: 0.7937 - val_loss: 0.4919 - val_recall: 0.7882
# Epoch 108/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4421 - recall: 0.7924 - val_loss: 0.4846 - val_recall: 0.7706
# Epoch 109/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4427 - recall: 0.7816 - val_loss: 0.4394 - val_recall: 0.7353
# Epoch 110/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4376 - recall: 0.7905 - val_loss: 0.4424 - val_recall: 0.7412
# Epoch 111/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4369 - recall: 0.7931 - val_loss: 0.4662 - val_recall: 0.7588
# Epoch 112/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4373 - recall: 0.7873 - val_loss: 0.4513 - val_recall: 0.7588
# Epoch 113/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4363 - recall: 0.7931 - val_loss: 0.4371 - val_recall: 0.7471
# Epoch 114/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4427 - recall: 0.7937 - val_loss: 0.4146 - val_recall: 0.7118
# Epoch 115/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4395 - recall: 0.7835 - val_loss: 0.4216 - val_recall: 0.7353
# Epoch 116/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4391 - recall: 0.7937 - val_loss: 0.4051 - val_recall: 0.7059
# Epoch 117/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4373 - recall: 0.7950 - val_loss: 0.4303 - val_recall: 0.7353
# Epoch 118/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4417 - recall: 0.7828 - val_loss: 0.4242 - val_recall: 0.7235
# Epoch 119/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4385 - recall: 0.7956 - val_loss: 0.4531 - val_recall: 0.7647
# Epoch 120/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4377 - recall: 0.7905 - val_loss: 0.4349 - val_recall: 0.7118
# Epoch 121/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4392 - recall: 0.7880 - val_loss: 0.4596 - val_recall: 0.7588
# Epoch 122/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4363 - recall: 0.7931 - val_loss: 0.4743 - val_recall: 0.7706
# Epoch 123/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4381 - recall: 0.7899 - val_loss: 0.4976 - val_recall: 0.7941
# Epoch 124/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4368 - recall: 0.7950 - val_loss: 0.5171 - val_recall: 0.7941
# Epoch 125/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4430 - recall: 0.7905 - val_loss: 0.4555 - val_recall: 0.7647
# Epoch 126/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4349 - recall: 0.7950 - val_loss: 0.4248 - val_recall: 0.7294
# Epoch 127/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4364 - recall: 0.7995 - val_loss: 0.4672 - val_recall: 0.7647
# Epoch 128/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4355 - recall: 0.7950 - val_loss: 0.4415 - val_recall: 0.7529
# Epoch 129/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4371 - recall: 0.7982 - val_loss: 0.4587 - val_recall: 0.7471
# Epoch 130/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4437 - recall: 0.7905 - val_loss: 0.4241 - val_recall: 0.7353
# Epoch 131/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4344 - recall: 0.7944 - val_loss: 0.4933 - val_recall: 0.7765
# Epoch 132/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4381 - recall: 0.7905 - val_loss: 0.4182 - val_recall: 0.7059
# Epoch 133/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4359 - recall: 0.7944 - val_loss: 0.4409 - val_recall: 0.7412
# Epoch 134/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4406 - recall: 0.7873 - val_loss: 0.5228 - val_recall: 0.8000
# Epoch 135/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4367 - recall: 0.7950 - val_loss: 0.4408 - val_recall: 0.7471
# Epoch 136/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4345 - recall: 0.8020 - val_loss: 0.4411 - val_recall: 0.7353
# Epoch 137/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4340 - recall: 0.7937 - val_loss: 0.4567 - val_recall: 0.7588
# Epoch 138/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4338 - recall: 0.7988 - val_loss: 0.4124 - val_recall: 0.7059
# Epoch 139/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4363 - recall: 0.7963 - val_loss: 0.4505 - val_recall: 0.7529
# Epoch 140/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4383 - recall: 0.7816 - val_loss: 0.4151 - val_recall: 0.7059
# Epoch 141/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4382 - recall: 0.8065 - val_loss: 0.4034 - val_recall: 0.6882
# Epoch 142/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4359 - recall: 0.7950 - val_loss: 0.4256 - val_recall: 0.7176
# Epoch 143/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4344 - recall: 0.7937 - val_loss: 0.5284 - val_recall: 0.8118
# Epoch 144/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4387 - recall: 0.7918 - val_loss: 0.4959 - val_recall: 0.7824
# Epoch 145/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4379 - recall: 0.7988 - val_loss: 0.4098 - val_recall: 0.7000
# Epoch 146/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4372 - recall: 0.7892 - val_loss: 0.4435 - val_recall: 0.7471
# Epoch 147/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4322 - recall: 0.8040 - val_loss: 0.4543 - val_recall: 0.7471
# Epoch 148/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4369 - recall: 0.7963 - val_loss: 0.4217 - val_recall: 0.7294
# Epoch 149/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4343 - recall: 0.7969 - val_loss: 0.4257 - val_recall: 0.7118
# Epoch 150/150
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4338 - recall: 0.8020 - val_loss: 0.4257 - val_recall: 0.7176

# %%
grid_model.best_score_ # best score according to the scoring function
# Out:
# 0.8191480119388233

# %%
grid_model.best_params_ # best parameters to get the best score
# Out:
# {'batch_size': 256,
#  'learn_rate': 0.004,
#  'optimizer': tensorflow.python.keras.optimizer_v2.adam.Adam}

# %%
y_pred = (grid_model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# WARNING:tensorflow:From C:\Users\madcat\anaconda3\envs\tfcpu\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# [[962 232]
#  [ 83 223]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1194
#            1       0.49      0.73      0.59       306
#
#     accuracy                           0.79      1500
#    macro avg       0.71      0.77      0.72      1500
# weighted avg       0.83      0.79      0.80      1500

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for grid_model

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\madcat\anaconda3\envs\tfcpu\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py:264: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.

# %%
grid_pre_score = average_precision_score(y_test, y_pred_proba)
grid_pre_score
# Out:
# 0.6888477792969291

# %%
grid_weighted_f1 = f1_score(y_test, y_pred)
grid_weighted_recall = recall_score(y_test, y_pred)

# %% [markdown]
# ## Model Comparission

# %%
compare = pd.DataFrame({"Model": ["ANN", "ANN_Weighted",  "ANN_Grid"],
                        "F1": [non_weighted_f1, weighted_f1, grid_weighted_f1],
                        "Recall": [non_weighted_recall, weighted_recall, grid_weighted_recall],
                        "AP": [non_weighted_pre_score, weighted_pre_score, grid_pre_score]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle # to save the model or scalling parameters

pickle.dump(col_transformer, open("transformer_churn", "wb"))
pickle.dump(scaler, open("scaler_churn", 'wb')) # to save the scaler

# %%
tf.random.set_seed(42)
model = Sequential()

model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer=Adam(learning_rate=0.004),
              loss="binary_crossentropy",
              metrics=["Recall"])

model.fit(x=X_train,
          y=y_train,
          validation_data=(X_test, y_test),
          callbacks=[early_stop, PlotLossesKerasTF()],
          batch_size=256,
          epochs=150,
          verbose=1,
          class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.460, max:    0.679, cur:    0.460)
# 	validation       	 (min:    0.432, max:    0.707, cur:    0.469)
# recall
# 	training         	 (min:    0.444, max:    0.783, cur:    0.782)
# 	validation       	 (min:    0.585, max:    0.853, cur:    0.752)
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4599 - recall: 0.7816 - val_loss: 0.4690 - val_recall: 0.7516
# Epoch 00037: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > .5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[972 222]
#  [ 95 211]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86      1194
#            1       0.49      0.69      0.57       306
#
#     accuracy                           0.79      1500
#    macro avg       0.70      0.75      0.72      1500
# weighted avg       0.82      0.79      0.80      1500

# %%
model.save('model_churn.h5')

# %% [markdown]
# ### Prediction

# %%
single_customer = df.drop('Exited', axis=1).iloc[[0]]
single_customer
# Out:
#            CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# RowNumber
# 1                  619    France  Female   42       2    0.000              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  customer_value
# RowNumber
# 1                  1               1       101348.880               3

# %%
single_customer1 = single_customer.copy()
single_customer1["Geography"] = "Germany"
single_customer1["Age"] = 45
single_customer1["Balance"] = 250000

# %%
single_customer1 = col_transformer.transform(single_customer1)
single_customer1
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 6.1900000e+02,
#         4.5000000e+01, 2.0000000e+00, 2.5000000e+05, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0134888e+05, 3.0000000e+00]])

# %%
single_customer1 = scaler.transform(single_customer1)
single_customer1
# Out:
# array([[1.        , 0.        , 0.        , 0.538     , 0.36486486,
#         0.2       , 1.04871244, 0.        , 1.        , 1.        ,
#         0.50673489, 0.5       ]])

# %%
model.predict(single_customer1)
# Out:
# array([[0.834241]], dtype=float32)

# %%
(model.predict(single_customer1) > 0.5).astype("int32")
# Out:
# array([[1]])

# %%
model.predict_classes(single_customer1)
# Out:
# array([[1]])

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Comparison with ML

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
clf1 = RandomForestClassifier(random_state=42, class_weight="balanced") 
clf2 = SVC(probability=True, random_state=42, class_weight="balanced")
clf3 = LogisticRegression(random_state=42, class_weight="balanced")

# %%
# Initilaze the hyperparameters for each dictionary
param1 = {}
param1['classifier__n_estimators'] = [10, 50, 100, 250]
param1['classifier__max_depth'] = [5, 10, 20]
param1['classifier'] = [clf1]

param2 = {}
param2['classifier__C'] = [10**(-2+i) for i in range(5)]
param2['classifier'] = [clf2]

param3 = {}
param3['classifier__C'] = [10**(-2+i) for i in range(5)]
param3['classifier__penalty'] = ['l1', 'l2']
param3['classifier'] = [clf3]

# %%
pipeline = Pipeline([('classifier', clf1)]) # pipeline to combine the classifiers
params = [param1, param2, param3] # list of dictionaries to tune the hyperparameters

# %%
grid_model = RandomizedSearchCV(pipeline, params, cv=5, n_jobs=-1,
                  scoring='recall').fit(X_train, y_train)

# %%
grid_model.best_params_ # best parameters to get the best score
# Out:
# {'classifier__C': 10,
#  'classifier': SVC(C=10, class_weight='balanced', probability=True, random_state=42)}

# %%
grid_model.best_score_ # best score according to the scoring function
# Out:
# 0.7204094551148573

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='RF')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6094546274152512

# %%
y_pred = grid_model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[947 247]
#  [ 95 211]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85      1194
#            1       0.46      0.69      0.55       306
#
#     accuracy                           0.77      1500
#    macro avg       0.68      0.74      0.70      1500
# weighted avg       0.82      0.77      0.79      1500

# %% [markdown]
# ---
# ---
